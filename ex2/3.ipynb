# %%
import torch as nn
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt

# %%
train_dataset = datasets.MNIST(root='./data', train=True, download=True, transform=transforms.ToTensor())
batch_size = 64
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

# %%
print(f"Number of training examples: {len(train_dataset)}")
image, label = train_dataset[0]
print(f"Image size: {image.size()}")
print(f"Label: {label}")
# Out:
# Number of training examples: 60000
# Image size: torch.Size([1, 28, 28])
# Label: 5

# %%
fig, axes = plt.subplots(nrows=3, ncols=3, figsize=(12, 5))
for i, ax in enumerate(axes.flat):
    image, label = train_dataset[i]
    ax.imshow(image.squeeze(), cmap='gray')
    ax.set_title(f"Label: {label}")
    ax.axis('off')
plt.tight_layout()
plt.show()

# %%
input_size = 28 * 28  
hidden_size = 128
output_size = 10  
model = MLP(input_size, hidden_size, output_size)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 4
#       2 hidden_size = 128
#       3 output_size = 10
# ----> 4 model = MLP(input_size, hidden_size, output_size)
#
# NameError: name 'MLP' is not defined

# %%
import torch.optim as optim


criterion = nn.CrossEntropyLoss()  
optimizer = optim.Adam(model.parameters(), lr=0.001) 

num_epochs = 10
losses=[]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 4
#       1 import torch.optim as optim
# ----> 4 criterion = nn.CrossEntropyLoss()
#       5 optimizer = optim.Adam(model.parameters(), lr=0.001)
#       7 num_epochs = 10
#
# File c:\Users\keshavaram\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\__init__.py:1938, in __getattr__(name)
#    1935     import importlib
#    1936     return importlib.import_module(f".{name}", __name__)
# -> 1938 raise AttributeError(f"module '{__name__}' has no attribute '{name}'")
#
# AttributeError: module 'torch' has no attribute 'CrossEntropyLoss'

# %%
for epoch in range(num_epochs):
    running_loss = 0.0
    for images, labels in train_loader:
        optimizer.zero_grad()  
        outputs = model(images) 
        loss = criterion(outputs, labels)  
        loss.backward()  
        optimizer.step()  

        running_loss += loss.item() * images.size(0)

    epoch_loss = running_loss / len(train_loader.dataset)
    print(f"Epoch [{epoch + 1}/{num_epochs}], Loss: {epoch_loss:.4f}")
    losses.append(loss.item())
# Out:
# Epoch [1/10], Loss: 0.3490
# Epoch [2/10], Loss: 0.1628
# Epoch [3/10], Loss: 0.1149
# Epoch [4/10], Loss: 0.0876
# Epoch [5/10], Loss: 0.0695
# Epoch [6/10], Loss: 0.0565
# Epoch [7/10], Loss: 0.0466
# Epoch [8/10], Loss: 0.0385
# Epoch [9/10], Loss: 0.0317
# Epoch [10/10], Loss: 0.0264

# %%
plt.plot(range(1,num_epochs+1),losses,label='Train Loss')

plt.xlabel('Epochs')
plt.ylabel('Loss Values')
plt.legend()
plt.show()
